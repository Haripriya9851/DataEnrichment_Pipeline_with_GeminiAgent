# %%
#install
# !pip install google-generativeai==0.7.2
# !pip install langchain-community
# !pip install crewai
# !pip install requests
# !pip install beautifulsoup4
# !pip install pandas
# Out:
# Requirement already satisfied: google-generativeai==0.7.2 in /usr/local/lib/python3.11/dist-packages (0.7.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.6 in /usr/local/lib/python3.11/dist-packages (from google-generativeai==0.7.2) (0.6.6)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai==0.7.2) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai==0.7.2) (2.174.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai==0.7.2) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai==0.7.2) (4.25.8)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai==0.7.2) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai==0.7.2) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai==0.7.2) (4.14.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.6->google-generativeai==0.7.2) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai==0.7.2) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai==0.7.2) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai==0.7.2) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai==0.7.2) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai==0.7.2) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai==0.7.2) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai==0.7.2) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai==0.7.2) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai==0.7.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai==0.7.2) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai==0.7.2) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai==0.7.2) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai==0.7.2) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai==0.7.2) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai==0.7.2) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai==0.7.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai==0.7.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai==0.7.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai==0.7.2) (2025.6.15)
# Collecting langchain-community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.67)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.4)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 34.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.0 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 1.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.1 langchain-community-0.3.27 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.10.1 python-dotenv-1.1.1 typing-inspect-0.9.0
# Collecting crewai
#   Downloading crewai-0.140.0-py3-none-any.whl.metadata (35 kB)
# Collecting appdirs>=1.4.4 (from crewai)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.9.0)
# Collecting chromadb>=0.5.23 (from crewai)
#   Downloading chromadb-1.0.15-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from crewai) (8.2.1)
# Collecting instructor>=1.3.3 (from crewai)
#   Downloading instructor-1.9.2-py3-none-any.whl.metadata (11 kB)
# Collecting json-repair==0.25.2 (from crewai)
#   Downloading json_repair-0.25.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting json5>=0.10.0 (from crewai)
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Collecting jsonref>=1.1.0 (from crewai)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting litellm==1.72.6 (from crewai)
#   Downloading litellm-1.72.6-py3-none-any.whl.metadata (39 kB)
# Collecting onnxruntime==1.22.0 (from crewai)
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.93.0)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai) (3.1.5)
# Collecting opentelemetry-api>=1.30.0 (from crewai)
#   Downloading opentelemetry_api-1.34.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.30.0 (from crewai)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.34.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.30.0 (from crewai)
#   Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting pdfplumber>=0.11.4 (from crewai)
#   Downloading pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (2.11.7)
# Requirement already satisfied: pyjwt>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (2.10.1)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.1.1)
# Collecting pyvis>=0.3.2 (from crewai)
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tokenizers>=0.20.3 in /usr/local/lib/python3.11/dist-packages (from crewai) (0.21.2)
# Collecting tomli-w>=1.1.0 (from crewai)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tomli>=2.0.2 (from crewai)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting uv>=0.4.25 (from crewai)
#   Downloading uv-0.7.19-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm==1.72.6->crewai) (3.11.15)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.72.6->crewai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.72.6->crewai) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm==1.72.6->crewai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.72.6->crewai) (4.24.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.72.6->crewai) (0.9.0)
# Collecting coloredlogs (from onnxruntime==1.22.0->crewai)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime==1.22.0->crewai) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime==1.22.0->crewai) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime==1.22.0->crewai) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime==1.22.0->crewai) (4.25.8)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime==1.22.0->crewai) (1.13.1)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Collecting pybase64>=1.4.1 (from chromadb>=0.5.23->crewai)
#   Downloading pybase64-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.35.0)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb>=0.5.23->crewai)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.14.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting pypika>=0.48.9 (from chromadb>=0.5.23->crewai)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb>=0.5.23->crewai)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.73.1)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (0.16.0)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.5.23->crewai)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.10.0)
# Collecting mkdocs-material>=9.5.49 (from instructor>=1.3.3->crewai)
#   Downloading mkdocs_material-9.6.15-py3-none-any.whl.metadata (19 kB)
# Collecting mkdocs>=1.6.1 (from instructor>=1.3.3->crewai)
#   Downloading mkdocs-1.6.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting pre-commit>=4.2.0 (from instructor>=1.3.3->crewai)
#   Downloading pre_commit-4.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (2.33.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (2.32.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.34.1 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.34.1 (from opentelemetry-exporter-otlp-proto-http>=1.30.0->crewai)
#   Downloading opentelemetry_proto-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf (from onnxruntime==1.22.0->crewai)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.55b1 (from opentelemetry-sdk>=1.30.0->crewai)
#   Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting pdfminer.six==20250506 (from pdfplumber>=0.11.4->crewai)
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai) (11.2.1)
# Collecting pypdfium2>=4.18.0 (from pdfplumber>=0.11.4->crewai)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (43.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai) (0.4.1)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (3.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.20.3->crewai) (0.33.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.72.6->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.72.6->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.72.6->crewai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.72.6->crewai) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.72.6->crewai) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.72.6->crewai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.72.6->crewai) (1.20.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (3.10)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm==1.72.6->crewai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->litellm==1.72.6->crewai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.72.6->crewai) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (1.1.5)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm==1.72.6->crewai) (3.23.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis>=0.3.2->crewai)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.72.6->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.6->crewai) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.6->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.6->crewai) (0.26.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.4.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting ghp-import>=1.0 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Downloading ghp_import-2.1.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: markdown>=3.3.6 in /usr/local/lib/python3.11/dist-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (3.8.2)
# Collecting mergedeep>=1.3.4 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting mkdocs-get-deps>=0.2.0 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Downloading mkdocs_get_deps-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathspec>=0.11.1 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting pyyaml-env-tag>=0.1 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Downloading pyyaml_env_tag-1.1-py3-none-any.whl.metadata (5.5 kB)
# Collecting watchdog>=2.0 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: babel~=2.10 in /usr/local/lib/python3.11/dist-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (2.17.0)
# Collecting backrefs~=5.7.post1 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Downloading backrefs-5.9-py311-none-any.whl.metadata (3.2 kB)
# Collecting colorama~=0.4 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting mkdocs-material-extensions~=1.3 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Downloading mkdocs_material_extensions-1.3.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting paginate~=0.5 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Downloading paginate-0.5.7-py2.py3-none-any.whl.metadata (11 kB)
# Collecting pymdown-extensions~=10.2 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Downloading pymdown_extensions-10.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb>=0.5.23->crewai)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting cfgv>=2.0.0 (from pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Downloading identify-2.6.12-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Downloading virtualenv-20.31.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime==1.22.0->crewai)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime==1.22.0->crewai) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (1.17.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.6.1->instructor>=1.3.3->crewai) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Downloading crewai-0.140.0-py3-none-any.whl (335 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.9/335.9 kB 11.0 MB/s eta 0:00:00
# Downloading json_repair-0.25.2-py3-none-any.whl (12 kB)
# Downloading litellm-1.72.6-py3-none-any.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 43.2 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 39.8 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading chromadb-1.0.15-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 17.2 MB/s eta 0:00:00
# Downloading instructor-1.9.2-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 6.8 MB/s eta 0:00:00
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading opentelemetry_api-1.34.1-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 3.7 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.34.1-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.34.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 2.6 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 6.3 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 5.8 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.7-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.6 MB/s eta 0:00:00
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 25.4 MB/s eta 0:00:00
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 29.3 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 16.0 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading uv-0.7.19-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.4/18.4 MB 54.4 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 16.7 MB/s eta 0:00:00
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 61.0 MB/s eta 0:00:00
# Downloading mkdocs-1.6.1-py3-none-any.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 73.9 MB/s eta 0:00:00
# Downloading mkdocs_material-9.6.15-py3-none-any.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 77.2 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.1 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl (18 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.0 MB/s eta 0:00:00
# Downloading pre_commit-4.2.0-py2.py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 13.5 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 19.2 MB/s eta 0:00:00
# Downloading pybase64-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 3.8 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 55.5 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading backrefs-5.9-py311-none-any.whl (392 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.1/392.1 kB 14.7 MB/s eta 0:00:00
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading ghp_import-2.1.0-py3-none-any.whl (11 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 22.1 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.2 MB/s eta 0:00:00
# Downloading identify-2.6.12-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 5.1 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 37.5 MB/s eta 0:00:00
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading mkdocs_get_deps-0.2.0-py3-none-any.whl (9.5 kB)
# Downloading mkdocs_material_extensions-1.3.1-py3-none-any.whl (8.7 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading paginate-0.5.7-py2.py3-none-any.whl (13 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pymdown_extensions-10.16-py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 12.7 MB/s eta 0:00:00
# Downloading pyyaml_env_tag-1.1-py3-none-any.whl (4.7 kB)
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 52.4 MB/s eta 0:00:00
# Downloading virtualenv-20.31.2-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 16.1 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 3.5 MB/s eta 0:00:00
# Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 19.9 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 18.6 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=2b85d9fc1f05f7f45f936ed0eb7b577f1b33868b52c976728cf0437edb210c65
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, paginate, durationpy, distlib, appdirs, watchdog, virtualenv, uvloop, uv, tomli-w, tomli, pyyaml-env-tag, pypdfium2, pymdown-extensions, pybase64, protobuf, pathspec, overrides, nodeenv, mmh3, mkdocs-material-extensions, mergedeep, jsonref, json5, json-repair, jedi, identify, humanfriendly, httptools, colorama, cfgv, bcrypt, backrefs, backoff, watchfiles, pre-commit, posthog, opentelemetry-proto, opentelemetry-api, mkdocs-get-deps, ghp-import, coloredlogs, pyvis, pdfminer.six, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, onnxruntime, mkdocs, kubernetes, pdfplumber, opentelemetry-sdk, mkdocs-material, litellm, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, instructor, chromadb, crewai
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.8
#     Uninstalling protobuf-4.25.8:
#       Successfully uninstalled protobuf-4.25.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.6 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.29.5 which is incompatible.
# Successfully installed appdirs-1.4.4 backoff-2.2.1 backrefs-5.9 bcrypt-4.3.0 cfgv-3.4.0 chromadb-1.0.15 colorama-0.4.6 coloredlogs-15.0.1 crewai-0.140.0 distlib-0.3.9 durationpy-0.10 ghp-import-2.1.0 httptools-0.6.4 humanfriendly-10.0 identify-2.6.12 instructor-1.9.2 jedi-0.19.2 json-repair-0.25.2 json5-0.12.0 jsonref-1.1.0 kubernetes-33.1.0 litellm-1.72.6 mergedeep-1.3.4 mkdocs-1.6.1 mkdocs-get-deps-0.2.0 mkdocs-material-9.6.15 mkdocs-material-extensions-1.3.1 mmh3-5.1.0 nodeenv-1.9.1 onnxruntime-1.22.0 opentelemetry-api-1.34.1 opentelemetry-exporter-otlp-proto-common-1.34.1 opentelemetry-exporter-otlp-proto-grpc-1.34.1 opentelemetry-exporter-otlp-proto-http-1.34.1 opentelemetry-proto-1.34.1 opentelemetry-sdk-1.34.1 opentelemetry-semantic-conventions-0.55b1 overrides-7.7.0 paginate-0.5.7 pathspec-0.12.1 pdfminer.six-20250506 pdfplumber-0.11.7 posthog-5.4.0 pre-commit-4.2.0 protobuf-5.29.5 pybase64-1.4.1 pymdown-extensions-10.16 pypdfium2-4.30.1 pypika-0.48.9 pyvis-0.3.2 pyyaml-env-tag-1.1 tomli-2.2.1 tomli-w-1.2.0 uv-0.7.19 uvloop-0.21.0 virtualenv-20.31.2 watchdog-6.0.0 watchfiles-1.1.0
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.6.15)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Working Code

# %%
import os
import json
import re
import pandas as pd
from langchain_community.utilities import GoogleSerperAPIWrapper
import google.generativeai as genai

import time
import requests

def safe_enrich(func, *args, retries=3, delay=2, **kwargs):
    for attempt in range(retries):
        try:
            return func(*args, **kwargs)
        except (requests.ConnectionError, requests.exceptions.RequestException) as e:
            print(f"Connection error: {e}. Retrying in {delay} seconds...")
            time.sleep(delay)
    print("Failed after retries.")
    return {}

# --- SETUP ---
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY", "YOUR-KEY")
os.environ["SERPER_API_KEY"] = os.getenv("SERPER_API_KEY", "YOUR-KEY")
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])
gemini_model = genai.GenerativeModel('gemini-2.5-flash')
serper = GoogleSerperAPIWrapper()
search = GoogleSerperAPIWrapper()

def extract_json(text):
    cleaned = re.sub(r"^```json\s*|```$", "", text.strip(), flags=re.MULTILINE)
    try:
        return json.loads(cleaned)
    except json.JSONDecodeError as e:
        print(f"JSON decode error: {e}")
        print(f"Cleaned text:\n{cleaned}")
        return {}

def format_name(name):
    name = re.sub(r'\s+', ' ', str(name).replace('\n', ' ')).strip().strip('"').strip("'")
    corp_terms = ['llc', 'inc', 'corp', 'ltd', 'company']
    if any(term in name.lower() for term in corp_terms):
        return name
    if ',' in name and name.count(',') == 1:
        last, first = name.split(',', 1)
        name = f"{first.strip()} {last.strip()}"
    return name

def clean_dataframe(df):
    df = df.copy()
    df.loc[:, 'Franchisee'] = df['Franchisee'].apply(format_name)
    df.loc[:, 'State'] = df['City'].str.strip() + ', ' + df['State'].str.strip()
    if 'FDD' in df.columns:
        df.loc[:, 'Franchise Name'] = df['FDD']
    return df.dropna(axis=1, how='all')

def search_web(query: str):
    results = search.results(query)

    # if isinstance(results, dict) and results.get('organic'):
    #     first_result = results['organic'][0]
    #     snippet = first_result.get('snippet', '')
    #     url = first_result.get('link', '')
    return results
    # return "", ""

def classify_franchisees(names):
    prompt = f"""Classify the following names as 'Individual' or 'Corporate':
{names}

Rules:
- Individual = Person name (John Doe)
- Corporate = Includes LLC, Inc, Ltd, Corp, Company, etc.

Return only valid JSON, in this format:
[{{"name": "Name", "type": "Individual/Corporate"}}]
No explanation. No markdown. No text before or after. If you cannot classify, return [].
"""
    response = gemini_model.generate_content(prompt)
    text = response.text.strip()
    #print("Gemini classification raw output:", repr(text))  # Debug print
    data = extract_json(text)
    if not data:
        print("Gemini returned empty or invalid output. Falling back to empty DataFrame.")
        return pd.DataFrame(columns=["name", "type"])
    return pd.DataFrame(data)

def enrich_individual(name, franchise, state):
    company_query = f"What company does {name} own that holds a {franchise} franchise in {state}?"
    snippet = search_web(company_query)
    #print(snippet)
    legal_name_prompt = f"From the following text, return the company name owned by {name} that is associated with {franchise}. If not found, return just '{name}'. No explanation.\n\n{snippet}"
    legal_name = gemini_model.generate_content(legal_name_prompt).text.strip()

    details_query = f"Details of {legal_name} in {state}, include corporate address, phone, and email"
    snippet2 = search_web(details_query)

    extract_prompt = f"""From the {snippet2}, extract corporate details along with Source URLs used for enrichment. return JSON:

{{
  "legal_corporate_name": "{legal_name}",
  "corporate_address": "",
  "corporate_phone": "",
  "corporate_email": "",
  "owner_name": "{name}",
  "linkedin_url": "",
  "Source URLs used for enrichment": ""
}}
No backtics(```),No markdown. Return only JSON"""
    response = gemini_model.generate_content(extract_prompt)
    text = response.text.strip()
    result = extract_json(text)

    return result

def enrich_corporate(name, state):
    query = f"Who owns or manages {name} in {state}?"
    snippet = search_web(query)
    extract_prompt = f"""From the following, extract business info along with Source URLs used for enrichment. return JSON:
{snippet}

{{
  "legal_corporate_name": "{name}",
  "corporate_address": "",
  "corporate_phone": "",
  "corporate_email": "",
  "owner_name": "",
  "linkedin_url": "",
  "Source URLs used for enrichment": ""
}}.
No backtics and markdown."""
    response = gemini_model.generate_content(extract_prompt)
    text = response.text.strip()
    print(f"Raw Gemini response:\n{text}")
    result = extract_json(text)
    # Always set the source_urls field to the actual URL

    return result

def enrich_all(df):
    df = clean_dataframe(df)
    names = df['Franchisee'].tolist()
    classifications_df = classify_franchisees(names)
    enriched_rows = []
    for _, row in df.iterrows():
        name = row['Franchisee']
        entity = classifications_df[classifications_df['name'].str.lower() == name.lower()]
        entity_type = entity['type'].values[0] if not entity.empty else "Unknown"
        state = row['State']
        franchise = row.get('Franchise Name', '')

        if entity_type == "Individual":
            enriched = safe_enrich(enrich_individual, name, franchise, state)
        elif entity_type == "Corporate":
            enriched = safe_enrich(enrich_corporate, name, state)
        else:
            enriched = {
                "legal_corporate_name": name,
                "corporate_address": "N/A",
                "corporate_phone": "N/A",
                "corporate_email": "N/A",
                "owner_name": "N/A",
                "linkedin_url": "N/A",
                "Source URLs used for enrichment": "N/A"
            }

        if isinstance(enriched, list):
            if len(enriched) > 0 and isinstance(enriched[0], dict):
                enriched = enriched[0]
            else:
                enriched = {}
        elif not isinstance(enriched, dict):
            enriched = {}

        default_keys = ["legal_corporate_name", "corporate_address", "corporate_phone", "corporate_email", "owner_name", "linkedin_url", "Source URLs used for enrichment"]
        for key in default_keys:
            if key not in enriched:
                enriched[key] = "N/A"

        enriched_rows.append({**row.to_dict(), "Type": entity_type, **enriched})

    return pd.DataFrame(enriched_rows)

def batch_iterable(iterable, batch_size):
    l = len(iterable)
    for ndx in range(0, l, batch_size):
        yield iterable[ndx:min(ndx + batch_size, l)]

if __name__ == "__main__":
    df = pd.read_excel("Golden Chick_DE_Takehome.xlsx")
    print("Original Sample:")
    print(df[['Franchisee', 'City', 'State']].head())
    enriched_rows = []
    for batch in batch_iterable(df.index.tolist(), 10):
        batch_df = df.loc[batch]
        enriched_batch = enrich_all(batch_df)
        enriched_rows.append(enriched_batch)
    enriched_df = pd.concat(enriched_rows, ignore_index=True)
    enriched_df.to_excel("enriched_franchisees_gemini.xlsx", index=False)
    print("\nSaved enriched data to enriched_franchisees_gemini.xlsx")
    print(enriched_df[['Franchisee', 'Type', 'owner_name', 'legal_corporate_name', 'corporate_address', 'Source URLs used for enrichment']].head())
# Out:
# Original Sample:
#                       Franchisee      City State
# 0                    Hagan, John      Waco    TX
# 1                    Hagan, John     Brady    TX
# 2        Adam Fried Chicken, LLC     Plano    TX
# 3               Kallos 153, Inc.  McKinney    TX
# 4  AIG-A Foods Enterprises,\nLLC     Acton    TX
# Raw Gemini response:
# {
#   "legal_corporate_name": "Adam Fried Chicken, LLC",
#   "corporate_address": "1718 14th St, Plano, TX 75074, US",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.mapquest.com/us/texas/adam-fried-chicken-420442742"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Kallos 153, Inc.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "AIG FOODS ENTERPRISES LLC",
#   "corporate_address": "Glen Rose, TX",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.dnb.com/business-directory/company-profiles.aig_foods_enterprises_llc.56d8fff88b0e851823d170b3403145e1.html"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "NJ Golden Tree LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "BO STOVER TAYLOR, LLC",
#   "corporate_address": "4005 Pinehurst Drive, Taylor, TX 76574",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Bo Stover",
#   "linkedin_url": "https://www.linkedin.com/in/bo-stover-54582226",
#   "Source URLs used for enrichment": "https://opencorporates.com/companies/us_tx/0802323568, https://www.bizapedia.com/tx/bo-stover-taylor-llc.html, https://www.linkedin.com/in/bo-stover-54582226"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Evergreen International LLC",
#   "corporate_address": "Helotes, TX",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Ben-Brac Ltd.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.irs.gov/pub/irs-soi/eo_tx.csv, https://data.texas.gov/views/8gur-z4cy/rows.csv?accessType=DOWNLOAD"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "
LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.restfinance.com/app/pdf/fdd/Golden-Chick-2022.pdf, http://www.roysecitycdc.org/, https://www.raisingcanes.com/, https://www.tdlr.texas.gov/dbproduction2/TowCompanies.csv, https://frac.org/wp-content/uploads/3.17-ListNAHO.pdf, https://www.facebook.com/groups/519872852719574/posts/1103910077649179/, https://www.health.ny.gov/regulations/hcra/elector/elect_p3.htm, https://www.indeed.com/q-restaurant-l-royse-city,-tx-jobs.html, https://www.roysecitycdc.org/news-center/p/item/52038/anvil-brewing-a-family-business-above-and-beyond-craft-beer, https://www.tripadvisor.com/Restaurant_Review-g56590-d6754244-Reviews-Sweet_Water_Grill-Royse_City-Texas.html"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Bo Stover Elgin-Giddings, LLC",
#   "corporate_address": "2650 Cr 450, Thrall, TX 76578",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Bo Stover",
#   "linkedin_url": "https://www.linkedin.com/in/bo-stover-54582226",
#   "Source URLs used for enrichment": "https://www.bizapedia.com/tx/bo-stover-elgin-giddings-llc.html, https://www.linkedin.com/in/bo-stover-54582226"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Best of Cluck, LLC",
#   "corporate_address": "Garland, TX",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "https://www.linkedin.com/company/best-of-cluck-llc",
#   "Source URLs used for enrichment": "https://www.corporationwiki.com/p/2jxnv7/best-of-cluck-llc, https://www.linkedin.com/company/best-of-cluck-llc, https://www.rockstrategic.com/, https://www.signalhire.com/companies/best-of-cluck-llc, https://ph.linkedin.com/company/best-of-cluck-llc"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Bo Stover Lockhart, LLC",
#   "corporate_address": "640 S Colorado St Lockhart, TX - 78644",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Bo Stover",
#   "linkedin_url": "https://www.linkedin.com/in/bo-stover-54582226",
#   "Source URLs used for enrichment": "https://www.dnb.com/contact-directory/contact-profile.bo_stover.cac424230648ac55577a6f473bdae1be.html, https://www.glassdoor.com/job-listing/guest-service-provider-golden-chick-JV_IC1139781_KO0,22_KE23,35.htm?jl=1009785374380, https://www.linkedin.com/in/bo-stover-54582226"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Kess Management Corporation",
#   "corporate_address": "2625 N JOSEY LN STE 114, CARROLLTON, TX, 75007, USA",
#   "corporate_phone": null,
#   "corporate_email": null,
#   "owner_name": "Yong Lee (Registered Agent)",
#   "linkedin_url": null,
#   "Source URLs used for enrichment": "https://opencorporates.com/companies/us_tx/0802659990"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "B & C Chicken, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "No direct information regarding the corporate address, phone, email, owner, or LinkedIn URL for B & C Chicken, LLC was found in the provided search results. The results either refer to different entities (e.g., B&C TRUCKS COMPANY LLC, Kp Chicken Llc, Wingstop, Wall Street Bar & Grill), are general directories/reports that do not contain specific details for the queried entity, or are located in different states."
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Itasca Express Mart, Inc.",
#   "corporate_address": "1201 South Files Street",
#   "corporate_phone": "(254) 687-9711",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.manta.com/mb_54_B619B_KLL/grocery_stores/itasca_tx"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Nam’s Family, Inc.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Irving Foods, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": [
#     "https://en.wikipedia.org/wiki/Irving_Group_of_Companies",
#     "https://chaacrestaurants.com/about/",
#     "https://www.linkedin.com/company/chaac-foods-restaurants",
#     "https://www.irvingtx.gov/",
#     "https://sowginc.com/",
#     "https://www.irvingconsumerproducts.com/",
#     "https://www.bbb.org/us/tx/irving/profile/food-wholesalers/melindas-foods-llc-0875-91141635",
#     "https://www.indeed.com/q-fast-food-l-irving,-tx-jobs.html",
#     "https://www.dnb.com/business-directory/company-information.accommodation_and_food_services.us.texas.irving.html?page=13",
#     "https://www.linkedin.com/company/four-leaf-ventures-llc"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Morium Enterprise, Inc.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "G.C. Dallas – Stemmons 2015, Ltd.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "BO STOVER ELGIN-GIDDINGS, LLC",
#   "corporate_address": "2650 Cr 450, Thrall, TX 76578",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Luke A Stover",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.bizapedia.com/tx/bo-stover-elgin-giddings-llc.html"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Bo Stover LaGrange, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://ftp.txdot.gov/pub/txdot/get-involved/ykm/us77/091923-documentation.pdf"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Nerway Fried Chicken, Inc.",
#   "corporate_address": "Allen, TX",
#   "corporate_phone": "972-424-4653",
#   "corporate_email": null,
#   "owner_name": "AMIR NERWAY",
#   "linkedin_url": null,
#   "Source URLs used for enrichment": [
#     "https://www.dnb.com/business-directory/company-profiles.nerway_fried_chicken_inc.ccfd93d65d85d45a8ae4459000ef7964.html",
#     "https://www.buzzfile.com/business/Nerway-Fried-Chicken,-Inc.-972-424-4653"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "G.C. Ft. Worth-Renaissance 2016, Ltd.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "DiamondRock Hospitality",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": [
#     "https://www.dfwi.org/item/pioneering-fort-worth-hotel-celebrates-40-years-with-a-showy-renovation-how-the-worthington-stays-relevant",
#     "https://www.remingtonhospitality.com/press-releases",
#     "https://www.tripadvisor.com/Hotel_Feature-g55857-d98856-zft6217-The_Worthington_Renaissance_Fort_Worth_Hotel.html"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Fried Right, LLC",
#   "corporate_address": "Bowie, TX",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://tx.biass.us/bowie/fried-right-llc-25205035b"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Bo Stover Belton, LLC",
#   "corporate_address": "Belton, TX",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Bo Stover",
#   "linkedin_url": "https://www.linkedin.com/in/bo-stover-54582226",
#   "Source URLs used for enrichment": "https://www.linkedin.com/in/bo-stover-54582226, https://www.mapquest.com/us/texas/bo-stover-enterprises-inc-369207336"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Crowley GC, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": [
#     "https://www.crowley.com/company-overview/",
#     "https://www.dnb.com/business-directory/company-profiles.gc_rouzan_llc.2119579615f6a5fe080e02f696477d7c.html",
#     "https://www.crowley.com/",
#     "https://walton.com/walton-acquires-296-acres-in-fort-worth-area-adding-to-its-land-portfolio-in-texas/",
#     "https://www.linkedin.com/in/jerry-kirkland",
#     "https://www.levelset.com/projects/texas/crowley/301-w-fm-1187-crowley-tx-76036/",
#     "https://www.procore.com/network/p/gandd-visions-concrete-crowley",
#     "https://www.levelset.com/projects/texas/crowley/landmark-at-crowley-crowley-tx-76036/",
#     "https://safer.fmcsa.dot.gov/query.asp?searchtype=ANY&query_type=queryCarrierSnapshot&query_param=USDOT&query_string=2467295",
#     "https://www.facebook.com/groups/crowleytalk/posts/2339806329687258/"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Belajai Enterprise, Inc.",
#   "corporate_address": "3605 RANCHERO RD, Plano, TX 75093",
#   "corporate_phone": "972-816-9001",
#   "corporate_email": "",
#   "owner_name": "YEASIN SAFKAT",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.dnb.com/business-directory/company-profiles.belajai_enterprise_inc.e3084a85b556f906538e9e87bb03e50e.html, https://www.buzzfile.com/business/Belkid-Enterprises,-Inc.-972-816-9001"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "FranBrands, Inc.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "G.C. Mesquite-Davis 2015, Ltd.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Delano & Delano, Ltd.",
#   "corporate_address": "514 Lobo Trail, Harker Heights, Texas 76548",
#   "corporate_phone": "(817) 698-3410",
#   "corporate_email": "",
#   "owner_name": "James Delano",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://cms3.revize.com/revize/bellcountytx/county_government/county_clerk/docs/plats/E/ESPRESSO%20ADDITION%20AMENDED.pdf, https://www.fastpeoplesearch.com/james-delano_id_G-5461304849911311293, https://www.truepeoplesearch.com/find/person/pxu46lr048499llrll29r"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name":
110926000000000010.pdf, https://mycpa.cpa.state.tx.us/staxpayersearch/processTaxpyer.do?tpNtrlId=5000266522407, https://eservices.gov.vg/gazette/sites/eservices.gov.vg.gazette/files/governmentandstatutorynotices/G00421.pdf, https://www.oid.ok.gov/wp-content/uploads/2019/11/011818_2017_AnnualReport-LicenseCompanies.pdf, https://www.tdi.texas.gov/commercial/lcamusepolicy.html"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "G.C. Ft. Worth – Altamesa 2016, Ltd.",
#   "corporate_address": "1131 ROCKINGHAM DR STE 250",
#   "corporate_phone": "(972) 831-0911",
#   "corporate_email": null,
#   "owner_name": "Jay Alexander",
#   "linkedin_url": null,
#   "Source URLs used for enrichment": [
#     "https://www.tdlr.texas.gov/TABS/Search/Print/TABS2022012938",
#     "https://www.mapquest.com/us/texas/g-c-ft-worth-altamesa-2016-ltd-379974609"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Bo Stover Enterprises, Inc.",
#   "corporate_address": "Hutto, Texas, United States",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Bo Stover",
#   "linkedin_url": "https://www.linkedin.com/in/bo-stover-54582226",
#   "Source URLs used for enrichment": [
#     "https://www.linkedin.com/in/bo-stover-54582226",
#     "https://www.yellowpages.com/hutto-tx/bo-stover-enterprises-inc"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "GC @ Spears Road, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": [
#     "https://www.cacb.uscourts.gov/sites/cacb/files/documents/notice-of-sales/SV-23-10270-VK_2.pdf",
#     "https://eplanning.blm.gov/public_projects/nepa/75541/102244/250019733/Master_NC_Index_03-12-2020.pdf",
#     "https://ai.fmcsa.dot.gov/hhg/SearchResults.asp?search=5&state=TX&sort=0d",
#     "https://dlcp.dc.gov/sites/default/files/dc/sites/DLCP/publication/attachments/2023%20Businesses%20with%20Reports%20Due_0.pdf",
#     "https://www.dcaa.mil/Portals/88/FY%202022%20Active%20Contractor%20Listing.pdf"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Silguero Enterprises, LLC",
#   "corporate_address": "925 Kansas St Robstown, TX 78380",
#   "corporate_phone": "(361)765-1393",
#   "corporate_email": "",
#   "owner_name": "Abel Silguero",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.dnb.com/business-directory/company-profiles.silguero_enterprises_llc.7cffa8e846090b5f43b40ed29f168e9d.html, https://www.bizapedia.com/tx/silguero-enterprises-llc.html, https://www.fastpeoplesearch.com/abel-silguero_id_G-3175409325465688950, https://www.cyberbackgroundchecks.com/detail/abel-silguero/pidnpzxqylbpaqymqmggbql"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Pointbreak Ventures, Inc.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.dnb.com/business-directory/company-profiles.pointbreak_ventures_inc.7509ce5be91c0c874fb5ca900e8d7954.html"
# }
# Raw Gemini response:
# {"legal_corporate_name": "MURPHYWYLIEGC LLC", "corporate_address": "", "corporate_phone": "", "corporate_email": "", "owner_name": "", "linkedin_url": "", "Source URLs used for enrichment": ""}
# Raw Gemini response:
# {
#   "legal_corporate_name": "RDR Investments GP",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": [
#     "https://www.mapquest.com/us/texas/gpm-investments-445005513",
#     "https://reportcenter.highered.texas.gov/reports/data/financial-documents-2020003628afr/",
#     "https://d1io3yog0oux5.cloudfront.net/_f96c6c25477fc441a081078345c911d5/graphicpkg/db/2265/21533/pdf/Investor-Presentation-March-2021.pdf",
#     "https://www.atf.gov/file/6586/download",
#     "https://sos.wyo.gov/Business/docs/22Q4Domestic.pdf",
#     "https://morrisbrown.edu/wp-content/uploads/2022/08/Instructional-Staff-Listing-with-Pic-VITA-TRANSCRIPT-VERIFICATION-8-13-2022.pdf",
#     "https://lslbc.louisiana.gov/contractor-search-out-of-state/",
#     "https://otscweb.tamu.edu/Reports/ActiveFertRegistrant.aspx",
#     "https://sos.ks.gov/publications/register/2002/Vol_21_No_35_August_29_2002_p_1431-1486.pdf",
#     "http://www.lslbc.louisiana.gov/wp-content/uploads/agenda_com_10152020.pdf"
#   ]
# }
# Raw Gemini response:
# {"legal_corporate_name": "LP SLV Golden", "corporate_address": "", "corporate_phone": "", "corporate_email": "", "owner_name": "", "linkedin_url": "", "Source URLs used for enrichment": ""}
# Raw Gemini response:
# {
#   "legal_corporate_name": "SABA Automotive, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Ellen Saba, Camille Saba",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.bbb.org/us/tn/bartlett/profile/auto-repair/saba-automotive-llc-0543-11000512"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "RUYI Incorporated",
#   "corporate_address": "410 W Kiest Blvd Dallas, TX, 75224-3404 United States",
#   "corporate_phone": null,
#   "corporate_email": null,
#   "owner_name": "Joseph Omobogie (contact for RUYI GC DUNCANVILLE LLC)",
#   "linkedin_url": null,
#   "Source URLs used for enrichment": [
#     "https://www.dnb.com/business-directory/company-profiles.ruyi_incorporated.14c1db663845581871688b595718c727.html",
#     "https://www.ziprecruiter.com/c/Ruyi-Incorporated/Job/General-Manager/-in-Duncanville,TX?jid=2a4a01a64bf951d7",
#     "https://www.ziprecruiter.com/co/Ruyi/Jobs",
#     "https://www.monster.com/job-openings/assistant-manager-duncanville-tx--36d13056-4110-406a-ac97-32fc946e163e",
#     "https://www.bizapedia.com/tx/ruyi-gc-duncanville-llc.html",
#     "https://www.dandb.com/businessdirectory/ruyiincorporated-dallas-tx-33017767.html",
#     "https://www.talent.com/view?id=168daed62f6d",
#     "https://www.talent.com/view?id=a99794e860e3"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "L&P Franchising, Ltd.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Paul Terry",
#   "linkedin_url": "https://www.linkedin.com/in/paul-terry-98002081",
#   "Source URLs used for enrichment": "https://www.linkedin.com/in/paul-terry-98002081"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "TAWARA Corporation",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "TCM Foods, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.tarrantcountytx.gov/content/dam/main/covid-cares/ROUND1SBAPaymentsasof10-13-2020FINAL.pdf, https://assets.comptroller.texas.gov/open-data-files/ifta.csv"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "RD Family Food Services, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Pilot Point Chicken Venture #1, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://developpilotpoint.com/business-search/?start=P, https://www.lincolninst.edu/app/uploads/legacy-files/gwipp/upload/sources/Texas/2022/tx_2022_biennialregistriesofreinvestmentzonesfor_taxabatementsandfortaxincrimentfinancing_texascomptrollerofpublicaccounts_2020.pdf, https://www.tripadvisor.com/Restaurant_Review-g56455-d21226265-Reviews-Uncle_Beto_s_Mexican_Restaurant-Pilot_Point_Texas.html, https://www.zillow.com/homedetails/500-E-White-St-Pilot-Point-TX-76258/27332519_zpid/, https://newspapers.swco.ttu.edu/bitstream/handle/20.500.12255/67806/Muenster_2009_12_18.pdf?sequence=1&isAllowed=y, https://zeta.creativecirclecdn.com/tcr/files/20240904-114539-d28-TCR-2024-09-05%20optimized.pdf, https://www.tripadvisor.com/Restaurant_Review-g56455-d4506249-Reviews-Nick_s_Italian_Restaurant-Pilot_Point_Texas.html, https://s3.amazonaws.com/pageturnpro2.com/Publications/202001/4661/93050/PDF/132248223897949219_RAA_AnnualReport2019_v33_bw_lr.pdf, https://www.facebook.com/groups/fortbendlocalbusiness/posts/10095778823819672/, https://newspapers.swco.ttu.edu/bitstream/handle/20.500.12255/298879/Big_Spring_Herald_1998_10_25.pdf?sequence=1&isAllowed=y"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "

#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Crescent Star Insurance Limited (Parent Company); Saqib Zaidi (Chief Operating Officer). Note: The company was set to merge with PICIC Insurance Limited.",
#   "linkedin_url": "https://pk.linkedin.com/in/saqib-zaidi-322a2914",
#   "Source URLs used for enrichment": [
#     "https://profit.pakistantoday.com.pk/2017/12/25/crescent-star-foods-set-to-become-1st-food-chain-to-get-listed-on-stock-exchange/",
#     "https://mettisglobal.news/crescent-star-foods-to-merge-with-picic-insurance/",
#     "https://www.investorslounge.com/article/article-blog/2340",
#     "https://docs.publicnow.com/E4A6397316BDEB80ED2041B2EF545EDC7FC0727B",
#     "https://www.dawn.com/news/1378732",
#     "https://profit.pakistantoday.com.pk/2017/12/26/picic-insurance-set-to-merge-into-crescent-star-foods/",
#     "http://www.cstarinsurance.com/Investor-Information/Associated-Companies",
#     "https://mettisglobal.news/corporate-alert-crescent-star-insurance-signs-a-mou-with-bil-foods-fatburger/",
#     "https://in.marketscreener.com/quote/stock/PICIC-INSURANCE-LIMITED-46699019/news/PICIC-Insurance-Limited-entered-into-an-agreement-to-acquire-Crescent-Star-Foods-Limited-34865170/",
#     "https://pk.linkedin.com/in/saqib-zaidi-322a2914"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "GC Restaurants SA, LLC",
#   "corporate_address": "San Antonio, TX",
#   "corporate_phone": "210-480-8577",
#   "corporate_email": "",
#   "owner_name": "Allen Tharp",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.buzzfile.com/business/Golden-Chick-210-480-8577, https://www.restfinance.com/app/pdf/fdd/Golden-Chick-2022.pdf, https://www.manta.com/c/mhhw3zp/gc-restaurants-sa-llc, https://www.govinfo.gov/content/pkg/USCOURTS-txwd-5_20-cv-01046/pdf/USCOURTS-txwd-5_20-cv-01046-0.pdf"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Golden Operating Corporation",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.dnb.com/business-directory/company-profiles.golden_operating_corporation.d0c7e009a6a0dda2acd407bc28fa598b.html"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Golden Operating Corporation",
#   "corporate_address": "1131 Rockingham Drive, Suite 250, Richardson, TX",
#   "corporate_phone": "Not found",
#   "corporate_email": "Not found",
#   "owner_name": "Mark Parmerlee (President)",
#   "linkedin_url": "Not found",
#   "Source URLs used for enrichment": "https://www.dnb.com/business-directory/company-profiles.golden_operating_corporation.d0c7e009a6a0dda2acd407bc28fa598b.html, https://opencorporates.com/companies/us_tx/0007957506, https://www.mapquest.com/us/texas/golden-operating-corp-291810559"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Golden Operating Corporation",
#   "corporate_address": "1131 Rockingham, Ste. 250, Richardson, TX",
#   "corporate_phone": "Not found in snippets",
#   "corporate_email": "Not found in snippets",
#   "owner_name": "Not found in snippets",
#   "linkedin_url": "Not found in snippets for the corporate entity or its owners/managers",
#   "Source URLs used for enrichment": "https://www.dnb.com/business-directory/company-profiles.golden_operating_corporation.d0c7e009a6a0dda2acd407bc28fa598b.html, https://goldenchick.com/contact/, https://www.restfinance.com/app/pdf/fdd/Golden-Chick-2022.pdf, https://opencorporates.com/companies/us_tx/0007957506, https://www.dnb.com/business-directory/company-profiles.golden_operating_corporation.0d6f8100c69ca6e4bf43b109d8eb7382.html"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "G.C. Wichita Falls -Airport 2017, Ltd.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "http://www.wichitafallstx.gov/DocumentView.asp?DID=1149, https://ntfronline.com/2017/02/february-2017-profile-leading-a-legacy-the-ellis-family-of-g-c-ranch/, https://minerathletics.com/news/2017/2/11/softball-four-run-second-liftss-t-past-colorado-school-of-mines-5-3.aspx, https://www.chromatographyonline.com/view/a-turnkey-protocol-for-detecting-taste-and-odor-compounds-in-drinking-and-surface-waters-by-gas-chrom
LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://trellis.law/doc/154970510/petition, https://docs.oklahomacounty.org/AssessorWP5/AN-R.asp?PropertyID=78538, https://oklahoma.gov/content/dam/ok/en/health/health2/aem-documents/protective-health/hrds/health-facility-systems/OwnershipReport-ADC-RC-AL-CC.pdf"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "McAllen GC, L.L.C.",
#   "corporate_address": "4501 N 23rd St, Mcallen, TX 78504, US",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "http://www.datalog.co.uk/browse/detail.php/CompanyNumber/USTX0801965759/CompanyName/MCALLEN+GC%2C+L.L.C., https://www.mapquest.com/us/texas/mcallen-gc-llc-368998443"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "TCM Foods LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "CC STIRLING VENTURES LLC",
#   "corporate_address": "Pearsall, TX",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "Family-owned business",
#   "linkedin_url": "https://www.linkedin.com/company/cc-stirling-ventures",
#   "Source URLs used for enrichment": "https://www.dnb.com/business-directory/company-profiles.cc_stirling_ventures_llc.a8901c00f5046bd08ec89600ed997ea1.html, https://www.ccsventures.com/, https://www.ccsventures.com/about-us-1, https://www.linkedin.com/company/cc-stirling-ventures"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "G.C. Houston - S Post Oak 2017, Ltd.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": ""
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Alimentos Integrados, LLC",
#   "corporate_address": "PO BOX 1023, DIMMITT, Texas 79027",
#   "corporate_phone": "806-731-0261",
#   "corporate_email": "",
#   "owner_name": "Emilio Chavez",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://highplainsobserverdumas.com/golden-chick-opens-in-dumas-p16432-1.htm, https://www.buzzfile.com/business/Little-Caesar!s-806-421-0462, https://www.tdlr.texas.gov/TABS/Search/Print/TABS2019001195, http://www.datalog.co.uk/browse/detail.php/CompanyNumber/USTX0801725412/CompanyName/ALIMENTOS+INTEGRADOS,+LLC, https://www.corporationwiki.com/p/2gq6e/alimentos-integrados-llc, https://www.tdlr.texas.gov/TABS/Search/Project/TABS2021001988"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Golden Operating Corporation",
#   "corporate_address": "1801 Royal Ln., Richardson, TX 75080",
#   "corporate_phone": "(972) 889-9911",
#   "corporate_email": "Not found in snippets",
#   "owner_name": "Mark Parmerlee (CEO/President)",
#   "linkedin_url": "https://www.linkedin.com/in/marshallfisco (Marshall Fisco, General Counsel)",
#   "Source URLs used for enrichment": [
#     "https://www.dnb.com/business-directory/company-profiles.golden_operating_corporation.d0c7e009a6a0dda2acd407bc28fa598b.html",
#     "https://system.privco.com/company/golden-operating-corporation",
#     "https://www.linkedin.com/in/marshallfisco",
#     "https://www.bbb.org/us/tx/richardson/profile/restaurants/golden-chick-corporate-office-0875-90423013",
#     "https://www.yelp.com/biz/golden-operating-corporation-richardson"
#   ]
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "G.C. Plano Independence 2016, Ltd.",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://content.civicplus.com/api/assets/tx-plano/601bc505-9248-444d-a375-07707384ea06/current-contract-list-1.21.2021.pdf, https://www.shermanresidential.com/communities/"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "Oceanwide Holdings, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "GFC Leasing (manager)",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www2.greenvillecounty.org/scjd/PublicIndex/PIImageDisplay.aspx?ctagency=23002&doctype=D&docid=1640613319907-675&HKey=7910210251115111119431151031146589676878104901155310169112678350111827977122818268119697310011943845765, https://www2.greenvillecounty.org/scjd/PublicIndex/PIImageDisplay.aspx?ctagency=23003&doctype=D&docid=1634838239127-322&HKey=981155312048548111573116907186867512056105908948761138757781148277751131154798821076510685100707389"
# }
# Raw Gemini response:
# {
#   "legal_corporate_name": "PPA55.B85, LLC",
#   "corporate_address": "",
#   "corporate_phone": "",
#   "corporate_email": "",
#   "owner_name": "",
#   "linkedin_url": "",
#   "Source URLs used for enrichment": "https://www.restfinance.com/app/pdf/fdd/Golden-Chick-2022.pdf"
# }
#
# Saved enriched data to enriched_franchisees_gemini.xlsx
#                      Franchisee        Type  owner_name  \
# 0                    John Hagan  Individual
# 1                    John Hagan  Individual  John Hagan
# 2       Adam Fried Chicken, LLC   Corporate
# 3              Kallos 153, Inc.   Corporate
# 4  AIG-A Foods Enterprises, LLC   Corporate
#
#         legal_corporate_name                  corporate_address  \
# 0        M5 ENTERPRISE, INC.
# 1                 John Hagan
# 2    Adam Fried Chicken, LLC  1718 14th St, Plano, TX 75074, US
# 3           Kallos 153, Inc.
# 4  AIG FOODS ENTERPRISES LLC                      Glen Rose, TX
#
#                      Source URLs used for enrichment
# 0  https://www.dnb.com/business-directory/company...
# 1
# 2  https://www.mapquest.com/us/texas/adam-fried-c...
# 3
# 4  https://www.dnb.com/business-directory/company...

# %%
# Fill NAs if NA in  /content/enriched_franchisees_gemini.xlsx
import pandas as pd

# Load the Excel file into a DataFrame
df = pd.read_excel('/content/enriched_franchisees_gemini.xlsx')
#fill NA
df.fillna('N/A', inplace=True)
# Save the DataFrame back to the same Excel file
df.to_excel('/content/enriched_franchisees_gemini.xlsx', index=False)
# Out:
# /tmp/ipython-input-11-3878410277.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('N/A', inplace=True)

# %% [markdown]
# ## NOT WORKING - TRIED WITH DASK PARELLISM

# %%
import os
import re
import json
import pandas as pd
import time
from dask import delayed, compute
from langchain_community.utilities import GoogleSerperAPIWrapper
import google.generativeai as genai

# Setup
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY", "AIzaSyB_zRgfdmObMachU5qkrNM-dAoG9Ae4Qgk")
os.environ["SERPER_API_KEY"] = os.getenv("SERPER_API_KEY", "4d17b38723a34498589c3edd102b7b4b175b65f3")
genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

search = GoogleSerperAPIWrapper()
gemini_model = genai.GenerativeModel('gemini-1.5-flash')

# Utils
def extract_json(text):
    cleaned = re.sub(r"^```json\s*|```$", "", text.strip(), flags=re.MULTILINE)
    try:
        return json.loads(cleaned)
    except json.JSONDecodeError:
        return {}

def format_name(name):
    name = re.sub(r'\s+', ' ', str(name).replace('\n', ' ')).strip().strip('"').strip("'")
    corp_terms = ['llc', 'inc', 'corp', 'ltd', 'company']
    if any(term in name.lower() for term in corp_terms):
        return name
    if ',' in name and name.count(',') == 1:
        last, first = name.split(',', 1)
        name = f"{first.strip()} {last.strip()}"
    return name

def clean_dataframe(df):
    df = df.copy()
    df['Franchisee'] = df['Franchisee'].apply(format_name)
    df['State'] = df['City'].str.strip() + ', ' + df['State'].str.strip()
    if 'FDD' in df.columns:
        df['Franchise Name'] = df['FDD']
    return df.dropna(axis=1, how='all')

def classify_franchisees(names):
    prompt = f"""Classify the following names as 'Individual' or 'Corporate':\n{names}\n\nRules:\n- Individual = Person name (John Doe)\n- Corporate = Includes LLC, Inc, Ltd, Corp, Company, etc.\n\nReturn only valid JSON, in this format:\n[{{"name": "Name", "type": "Individual/Corporate"}}]\nNo explanation. No markdown. If unknown, return []."""
    response = gemini_model.generate_content(prompt)
    return pd.DataFrame(extract_json(response.text.strip()))

def search_web(query: str):
    return search.results(query)

def safe_enrich(func, *args, retries=5, delay=5, **kwargs):
    for attempt in range(retries):
        try:
            return func(*args, **kwargs)
        except Exception as e:
            if "429" in str(e) or "TooManyRequests" in str(e):
                print(f"[429] Rate limit hit. Retrying in {delay} seconds...")
                time.sleep(delay)
                delay *= 2
            else:
                print(f"[ERROR] {e}. Retrying in {delay} seconds...")
                time.sleep(delay)
    return {}

def enrich_individual(name, franchise, state):
    query1 = f"What company does {name} own that holds a {franchise} franchise in {state}?"
    snippet = search_web(query1)
    prompt1 = f"From this text, return company name owned by {name} for {franchise}. If not found, return '{name}'.\n{snippet}"
    legal_name = gemini_model.generate_content(prompt1).text.strip()

    query2 = f"Details of {legal_name} in {state}, include address, phone, email."
    snippet2 = search_web(query2)
    extract_prompt = f"""From this data, extract:
{{
  "legal_corporate_name": "{legal_name}",
  "corporate_address": "",
  "corporate_phone": "",
  "corporate_email": "",
  "owner_name": "{name}",
  "linkedin_url": "",
  "Source URLs used for enrichment": ""
}}
Return JSON only. No markdown or text.
{snippet2}"""
    result = gemini_model.generate_content(extract_prompt).text.strip()
    return extract_json(result)

def enrich_corporate(name, state):
    query = f"Who owns or manages {name} in {state}?"
    snippet = search_web(query)
    extract_prompt = f"""From this data, extract:
{{
  "legal_corporate_name": "{name}",
  "corporate_address": "",
  "corporate_phone": "",
  "corporate_email": "",
  "owner_name": "",
  "linkedin_url": "",
  "Source URLs used for enrichment": ""
}}
Return JSON only. No markdown or text.
{snippet}"""
    result = gemini_model.generate_content(extract_prompt).text.strip()
    return extract_json(result)

@delayed
def enrich_row(row_dict):
    name = row_dict["Franchisee"]
    state = row_dict["State"]
    franchise = row_dict.get("Franchise Name", "")

    try:
        entity_type_df = classify_franchisees([name])
        entity_type = entity_type_df['type'].values[0] if not entity_type_df.empty else "Unknown"

        if entity_type == "Individual":
            enriched = safe_enrich(enrich_individual, name, franchise, state)
        elif entity_type == "Corporate":
            enriched = safe_enrich(enrich_corporate, name, state)
        else:
            enriched = {}
    except Exception:
        enriched = {}

    defaults = {
        "legal_corporate_name": name,
        "corporate_address": "N/A",
        "corporate_phone": "N/A",
        "corporate_email": "N/A",
        "owner_name": name,
        "linkedin_url": "N/A",
        "Source URLs used for enrichment": "N/A",
        "Type": entity_type if 'entity_type' in locals() else "Unknown"
    }
    enriched = {**defaults, **enriched}
    return {**row_dict, **enriched}

def run_dask_enrichment(df):
    df = clean_dataframe(df)
    tasks = [enrich_row(row._asdict()) for row in df.itertuples(index=False)]
    results = compute(*tasks, scheduler='threads', num_workers=3)
    return pd.DataFrame(results)

if __name__ == "__main__":
    input_df = pd.read_excel("/content/Gra_1_50.xlsx")
    enriched_df = run_dask_enrichment(input_df)
    enriched_df.to_excel("enriched_franchisees_dask.xlsx", index=False)
    print("Saved to enriched_franchisees_dask.xlsx")
# Out:
# Saved to enriched_franchisees_dask.xlsx
